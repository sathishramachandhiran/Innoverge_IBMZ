# %% [markdown]
# <a href="https://colab.research.google.com/github/sathishramachandhiran/Innoverge_IBMZ/blob/main/ibmdatathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load datasets
hospitals_data = pd.read_csv('/content/hospitals_data.csv')
hiv_data = pd.read_csv('/content/hiv_data.csv')
health_indicator_data = pd.read_csv('/content/health_indicator_data.csv')
# symptoms_data = pd.read_csv('/content/large_data.csv')
facility_rating_data = pd.read_csv('/content/facility_rating_data .csv')
income_data = pd.read_csv('/content/income_data.csv')
diabetes_data = pd.read_csv('/content/diabetes_data.csv')
alcohol_data = pd.read_csv('/content/alcohol_data.csv')
tb_tobacco_data = pd.read_csv('/content/tb_tobacco_data.csv')
hepatitis_data = pd.read_csv('/content/hepatitis_data.csv')
population_density_data = pd.read_csv('/content/population_density_data.csv')
geographical_data = pd.read_csv('/content/geographical_data.csv')
malnutrition_data = pd.read_csv('/content/malnutrition_data.csv')
# waterpollution_data = pd.read_csv('/content/water_dataX.csv')
air_pollution_data = pd.read_csv('/content/air_pollution_data.csv')

# View the first few rows of each dataset (optional)
print(hospitals_data.head())
print(hiv_data.head())
print(health_indicator_data.head())
# Out:
#          States/UTs Number of hospitals in public sector  \
# 0       Lakshadweep                                    9
# 1        Chandigarh                                    9
# 2  Dadra & N Haveli                                   12
# 3        Puducherry                                   14
# 4       Daman & Diu                                    5
#
#   Number of hospitals in private sector  \
# 0                                     4
# 1                                     4
# 2                                     6
# 3                                     6
# 4                                    21
#
#   Total number of hospitals (public+private)
# 0                                         13
# 1                                         13
# 2                                         18
# 3                                         20
# 4                                         26
#        Country Reported number of people receiving ART  \
# ...

# %%
# Example of feature engineering
data['hospital_per_capita'] = data['hospital_count'] / data['population_density']
data['total_pollution'] = data['air_pollution'] + data['water_pollution']
data['health_score'] = data['income'] * data['facility_rating'] / (data['diabetes'] + data['malnutrition'])

# Handle missing values
data.fillna(method='ffill', inplace=True)

# Display the modified data
print(data[['hospital_per_capita', 'total_pollution', 'health_score']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-11f7baed8561> in <cell line: 2>()
#       1 # Example of feature engineering
# ----> 2 data['hospital_per_capita'] = data['hospital_count'] / data['population_density']
#       3 data['total_pollution'] = data['air_pollution'] + data['water_pollution']
#       4 data['health_score'] = data['income'] * data['facility_rating'] / (data['diabetes'] + data['malnutrition'])
#       5
#
# NameError: name 'data' is not defined
